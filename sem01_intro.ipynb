# %% [markdown]
# <a href="https://colab.research.google.com/github/vddavydova/colab/blob/main/sem01_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DAP: class_0_introduction

# %% [markdown]
# ______

# %% [markdown]
# # План на сегодня:
# * знакомство;
# * обозначение основных моментов по реализации курса;
# * ответы на вопросы, зачем все это.

# %% [markdown]
# ______

# %% [markdown]
# # Контакты

# %% [markdown]
# **Преподаватель**: Давыдова Виолетта Дмитриевна

# %% [markdown]
# ![contact1.png](data:image/png;base64,...)

# %% [markdown]
# * **почта:** vddavydova_2@edu.hse.ru
# * **телеграмм:** @davydovaviolet
# * **чат групп курса в телеграмме:** https://t.me/+LMtvX1XIPVA3NWMy

# %% [markdown]
# # Самый важный вопрос

# %% [markdown]
# ### Что по оценке?

# %% [markdown]
# Оценка по онлайн-курсу.

# %% [markdown]
# # Большой план маленьких побед

# %% [markdown]
# ### Что будем делать?

# %% [markdown]
# | модуль  | содержание  |
# | :-------- | :-------- |
# | 0. Организационные вопросы | _основные моменты реализации курса и инструменты для изучения_|
# | 1. Целые числа, ввод-вывод, простые операции со строками | _простейшемий ввод-вывод данных и применение арифметических операций для целых чисел._|
# | 2. Условный оператор и цикл while | _логические выражения и использование ветвления и циклов._|
# | 3. Вещественные числа | _новые типы данных – вещественные числа, которые широко используются при решении реальных задач и имеют свои особенности._|
# | 4. Функции и рекурсия | _создание и использование функций, которые позволяют повторно использовать код и делать его более структурированным._|
# | 5. Кортежи, цикл for, списки | _коллекции элементов – кортежи и списки, а также цикл for, который позволяет перебирать элементы коллекций._|
# | 6. Сортировка | _применение сортировки данных, которая облегчает решение многих задач и широко используется на практике._|
# | 7. Множества и словари | _новые структуры данных – множества и словари, которые позволяют эффективно сопоставлять различные объекты и широко используются в самых разных задачах._|
# | 8. Функциональное программирование | _стандартные функции языка Python для обработки последовательностей и разные парадигмы программирования и их сферы применения._|
# | 9. Классы | _основы объектно-ориентированного программирования – парадигмы, которые позволяют создавать и поддерживать большие проекты._|

# %% [markdown]
# # Литература

# %% [markdown]
# ### Читать? Нет. Пробовать.

# %% [markdown]
# *  Язык программирования Python: практикум : учеб. пособие / Р.А. Жуков. — М. : ИНФРА-М, 2019. — 216 с. + Доп. материалы [Электронный ресурс; Режим доступа: http://www.znanium.com]. — (Высшее образование: Бакалавриат). www.dx.doi.org/10.12737/textbook_5cb5ca35aaa7f5.89424805.

# %% [markdown]
# - Северенс Ч. — Введение в программирование на Python — Национальный Открытый Университет "ИНТУИТ" — 2016 - 231с. — ISBN: — Текст электронный // ЭБС ЛАНЬ — URL: https://e.lanbook.com/book/100703

# %% [markdown]
# - Сузи Р.А. — Язык программирования Python — Национальный Открытый Университет "ИНТУИТ" — 2016 — 350с. — ISBN: 5-9556-0058-2 — Текст электронный // ЭБС ЛАНЬ — URL: https://e.lanbook.com/book/100546

# %% [markdown]
# # ПО

# %% [markdown]
# ### Где мы будем работать?

# %% [markdown]
# ![anaconda3.png](data:image/png;base64,...)

# %% [markdown]
# Jypyter = [Anaconda](https://www.anaconda.com/products/individual)

# %% [markdown]
# Jupyter Notebook — интерактивная среда для запуска программного кода в браузере. Удобный инструмент для анализа данных, который используется многоми специалистами по data science.

# %% [markdown]
# Anaconda — это дистрибутив, т.е. набор ПО. После установки будет доступен Anaconda Navigator, подробнее о
# нем тут.
# Из Навигатора можно становить разные приложения. Например, Spyder — легкую IDE для разработки на Python.
# В Anaconda есть свой менеджер пакетов — conda.
# Самое главное — оттуда можно установить и запустить Jupyter.

# %% [markdown]
# ![img10.png](data:image/png;base64,...)

# %% [markdown]
# Jupyter = [Google Colab](https://colab.research.google.com/notebooks/intro.ipynb)

# %% [markdown]
# Если Вы не хотите устанавливать Anaconda, то можно воспользоваться облачным решением, например, Google Colab.
# Для работы в Colab Вам потребуется аккаунт Google.
#
# Преимущества: возможность использовать облачные сервера с высокопроизводительными процессорами прямо из ноутбука; интеграция с Github; возможность выгрузки данных из Google Таблиц; интеграция со StackOverflow; постоянная возможность бесплатного доступа.

# %% [markdown]
# Проще говоря, работаем с так называемыми ноутбуками и оформляем их с помощью языка маркдауна.
#
# [Markdown](https://github.com/adam-p/markdown-here/wiki/Markdown-Here-Cheatsheet)
# — это облегченный язык разметки, который является инструментом преобразования кода в HTML. Главной особенностью данного языка является максимально простой синтаксис, который служит для упрощения написания и чтения кода разметки, что, в свою очередь, позволяет легко его корректировать.

# %% [markdown]
# Поэтому установите Anaconda. [Инструкция для windows](https://github.com/hse-econ-data-science/dap_2020_fall/blob/master/utils/install_conda_windows.pdf) и [инструкция для мака](https://github.com/hse-econ-data-science/dap_2020_fall/blob/master/utils/install_conda_mac.pdf).

# %% [markdown]
# _p.s._ можно поробовать еще [онлайн интерпретатор `replit.com`](https://replit.com). Решать онлайн **Create Repl** -> **Select Language** -> **Python**.

# %% [markdown]
# ### Инструкция на все случаи жизни:

# %% [markdown]
# * **Как создать новую ячейку?**

# %% [markdown]
# > просто нажать `+` (insert cell below).

# %% [markdown]
# * **Как запустить код в ячейке?**

# %% [markdown]
# > Выделить ячейку и нажать `Run` или `Cntr`+`Enter` (см. Keyboard - Shortcuts).

# %% [markdown]
# * **Как понять, что код успешно выполнен?**

# %% [markdown]
# > Под ячейкой не появилос сообщения об ошибках + поле `In []` содержит число, а не символ `*`.

# %% [markdown]
# * **Что делать, если код не хочет успешно выполняться, поле слева выглядит вот так `In [*]` и вообще все зависло ааа помогите**

# %% [markdown]
# ![img2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# > Для прерывания выполнения кода можно попробовать нажать кнопку `▪` (interrapt the kernel) в панели наверху, либо перезапустить весь проект, нажав соседнюю кнопку (restart the kernel).

# %%
2+5
# Out:
# 7

# %%
a = 5

# %%
a
# Out:
# 5

# %% [markdown]
# ### Меньше текста, больше кода!

# %% [markdown]
# Напутствие:
# * главное, не бояться писать код, каким бы неправильным он не казался
# * скорее всего, ничего такого, что не починится в рамках Jupyter Norebook, вы сделать не сможете

# %% [markdown]
# ### Немного лирики

# %% [markdown]
# # Зачем мне все это нужно?

# %% [markdown]
# `Что такое Python?`
#
# Python (или просто питон) — простой, но в то же время достаточно мощный язык программирования, позволяющий упрощать выполнение задач практически в любой науке или индустрии.
#
# С его помощью можно собирать, обрабатывать и визуализировать данные самого разного характера.

# %% [markdown]
# ![img3.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# `Почему все вокруг учат Python?`
#
# Python – один из самых простых в освоении и популярных языков программирования.
#
# В современном мире программирование нужно не только программистам. Этот навык становится новой азбукой, а знание языка Python можно сравнить со знанием английского.

# %% [markdown]
# ![img4.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# `А зачем это умение мне?`
#
# В своей профессиональной деятельности, учебе, да и вообще в жизни, мы часто сталкиваемся со скучными рутинными задачами, которые хочется автоматизировать, или большими объемами данных, с которыми сложно работать.
#
# Питон позволяет автоматизировать рутинные операции и оставить все самое скучное машине, а также работать с данными, разобраться с которыми вручную или с помощью электронных таблиц попросту невозможно. Python сохраняет время и усилия для действительно важного!

# %% [markdown]
# ![img5.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# `А можно подробнее?`
#
# Собрать однотипные данные с подстраниц одного сайта, отсортировать таблицы с данными по сложным условиям и объединять их между собой за несколько секунд, посчитать количество супермаркетов в окрестностях любой точки мира и сделать для всего этого интерактивную визуализацию — всё это (а также многое другое) можно сделать, используя инструменты Python.

# %% [markdown]
# ![img6.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# `Звучит интересно, но что мне дадут эти знания и навыки?`
#
# Благодаря навыкам программирования и анализа данных выпускники Вышки становятся более универсальными специалистами и получают конкурентное преимущество на рынке труда.
#
# Даже если вы не будете работать в индустрии, связанной с данными, вы сможете использовать эти навыки в жизни, например, собирать информацию в интернете или автоматизировать бытовые задачи. Приятный бонус — возможность проводить актуальные исследования на стыке IT и других предметных областей.

# %% [markdown]
# ![img7.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Несколько личных примеров из учебы и практики

# %% [markdown]
# * **Estimating ML-Models Financial Impact** (онлайн-курс 2 курс МП)

# %% [markdown]
# * **Unstructured Data Analysis** (курс Московской Вышки, очень советую!)

# %% [markdown]
# * **Финансовая эконометрика, Прикладные вопросы эконометрики, Проектная работа, КР и ВКР**

# %%
# загрузка необходимых библиотек
import pandas as pd
import matplotlib.pyplot as plt

# %%
# загрузка и просмотр данных для работы
abspath = 'C:/Users/Виолетта/Desktop/Финансовая эконометрика/ДКР/'
data = pd.read_excel(abspath + 'data2021.xlsx', index_col=0)
data.head()
# Out:
#              PI  UNEM     M2       DLM     USDRUB     DLUSD
# DATE
# 2000-01-01  2.3  12.2  714.6  7.419409  28.253333  5.300503
# 2000-02-01  1.0  12.1  709.6 -0.702151  28.724286  1.653151
# 2000-03-01  0.6  11.4  742.0  4.464781  28.457727 -0.932322
# 2000-04-01  0.9  10.8  768.4  3.496119  28.595238  0.482047
# 2000-05-01  1.8  10.2  802.5  4.342142  28.306316 -1.015525

# %%
# описательный анализ данных
data.describe()
# Out:
#                PI        UNEM            M2         DLM      USDRUB  \
# count  254.000000  254.000000    254.000000  254.000000  254.000000
# mean     0.769252    6.725984  20645.687402    1.757371   39.954504
# std      0.646130    1.647118  16629.097490    3.079820   16.492147
# min     -0.540000    4.300000    709.600000  -12.677358   23.347896
# 25%      0.360000    5.300000   4491.400000    0.352655   28.570146
# 50%      0.615000    6.300000  16982.100000    1.340198   31.022320
# 75%      1.007500    8.100000  32330.250000    2.850542   57.733031
# max      3.850000   12.200000  58652.100000   12.266201   77.934425
#
#             DLUSD
# count  254.000000
# mean     0.401626
# std      3.464252
# min    -12.596807
# 25%     -1.246020
# 50%     -0.013762
# 75%      1.061333
# max     18.788574

# %% [markdown]
# `PI` – темп инфляции для каждого месяца по индексу потребительских цен в процентах;
#
# `UNEM` – уровень безработицы в процентах;
#
# `M2` – денежная масса (агрегат M2) в млрд. руб.;
#
# `DLM` = 100ln(M2/M2(-1)) – темп роста денежной массы в процентах;
#
# `USDRUB` – курс доллара США в рублях;
#
# `DLUSD` = 100ln(USDRUB/USDRUB(-1)) – темп роста курса доллара в процентах.

# %%
# визуализация USDRUB

plt.hist(data.USDRUB, bins=40)
plt.show()

# %% [markdown]
# * **Тестовое задание на позицию data scientist в Сбер**

# %% [markdown]
# > Направляю задание по мотивам нашего сегодняшнего собеседования. Дано: цены по 4500 бриллиантам и факторы, влияющие на них (строки 4-4503). Задача: спрогнозировать цены на оставшиеся 1500 бриллиантов (строки 4504-6003). Как обсуждали на собеседовании, перед построением модели нужно проанализировать данные.

# %% [markdown]
# ![test.png](data:image/png;base64,...)

# %%
# загрузка датасета
data = pd.read_csv('C:\\Users\\Виолетта\\Desktop\\data.csv', sep=';', encoding='latin1')

# %%
# вывод датасета
data.head()
# Out:
#     ID  Carat Weight    Cut Color Clarity Polish Symmetry Report   Price
# 0  1.0          1.10  Ideal     H     SI1     VG       EX    GIA  5169.0
# 1  2.0          0.83  Ideal     H     VS1     ID       ID   AGSL  3470.0
# 2  3.0          0.85  Ideal     H     SI1     EX       EX    GIA  3183.0
# 3  4.0          0.91  Ideal     E     SI1     VG       VG    GIA  4370.0
# 4  5.0          0.83  Ideal     G     SI1     EX       EX    GIA  3171.0

# %% [markdown]
# # Резюме за сегодня:
#
# * Работать будем с Jupyter Notebook из комплекта программ Anaconda. Файлы этой программы называются блокнотами — в них можно как писать команды для компьютера на языке Python, так и пояснения к программам на естественном языке (русском, например).
# * Для результативного взаимодействия добавиться в группу, если есть желание.
# * Пробовать. Это интересно.
