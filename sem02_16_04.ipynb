# %% [markdown]
# <a href="https://colab.research.google.com/github/vddavydova/colab/blob/main/sem02_16_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # dap-spring-2022
#
# ## Семинар 2. Условный оператор if-else, циклы while и for

# %% [markdown]
# **ЗАДАЧА 1. Распродажа**
#
# В магазине проходит акция:
#
# На все товары дешевле 1000 рублей скидка 15%
#
# На все товары дороже либо равно 1000, но дешевле либо равно 5000 рублей скидка 20%
#
# На все товары дороже 5000 рублей скидка 25%
#
# ВВОД
# Целое неотрицательное число - цена товара в рублях
#
# ВЫВОД
# Целое неотрицательное число - цена товара с учётом скидки в рублях

# %%
# ваш код

# %% [markdown]
# **ЗАДАЧА 2. Хитрости умножения**
#
# Для умножения двузначного числа на 11 есть интересная хитрость: результат произведения можно получить если между первой и второй цифрой исходного числа вписать сумму этих цифр. Например, 15 11 = 1 1+5 5 = 165 или 34 11 = 3 3+4 4 = 374. Реализуйте программу, которая умножала бы двузначные числа на 11, используя эту хитрость. Пользоваться оператором умножения нельзя.
#
# ВВОД
# Вводится двузначное число.
#
# ВЫВОД
# Программа должна вывести ответ на задачу.
#
# Тест 1
#
# Пример ввода:
#
# 15
#
# Вывод:
#
# 165
#
# Тест 2
#
# Пример ввода:
#
# 66
#
# Вывод:
#
# 726

# %%
# ваш код

# %% [markdown]
# **ЗАДАЧА 3. Беги, герой!**
#
# Вася начал бегать и в первый день он пробежал X километров и выдохся. Вася поставил себе цель Y километров и решил узнать, когда он ее достигнет, если каждый день будет бегать дистанцию на 10% больше, чем в предыдущий.
#
# ВВОД Программа получает на вход целые числа X, Y
#
# ВЫВОД Одно целое число (день, когда Вася пробежит свою цель)
#
# Примеры
#
# Ввод:
# 10
# 21
#
# Вывод:
# 9

# %%
# ваш код

# %% [markdown]
# **ЗАДАЧА 4. Сумма**
#
# Пройтись в цикле по элементам списка и посчитать их сумму.
#
# ВВОД
# Программа получает на вход числа через пробел.
#
# ВЫВОД
# Сумма элементов списка.

# %%
# ваш код

# %% [markdown]
# **ЗАДАЧА 5. Наименьшее из положительных**
#
# Выведите значение наименьшего из всех положительных элементов в списке. Известно, что в списке есть хотя бы один положительный элемент, а значения всех элементов списка по модулю не превосходят 1000.
#
# ВВОД
# Вводится список чисел. Все числа списка находятся на одной строке.
#
# ВЫВОД
# Выведите ответ на задачу.
#
# Пример 1
#
# Ввод
#
# 5 -4 3 -2 1
#
# Вывод
#
# 1
#
# Пример 2
#
# Ввод
#
# 10 5 0 -5 -10
#
# Вывод
#
# 5
#
# Пример 3
#
# Ввод
#
# -1 -2 -3 -4 100
#
# Вывод
#
# 100

# %%
# ваш код

# %% [markdown]
# ## Задачи на условные вероятности*

# %%
# модуль, который поможет при решении
from random import randint

# %% [markdown]
# **ЗАДАЧА 6. Удав Анатолий**
#
# Удав Анатолий любит французские багеты. Длина французского багета равна 1 метру. За один заглот Удав Анатолий заглатывает
# кусок случайной длины равномерно распределенной на отрезке [0; 1]. Для того, чтобы съесть весь багет удаву потребуется случайное количество N заглотов.
# Оцените $P(N=2), P(N=3), E(N)$

# %%
#ваше решение здесь
def esh_baget():
    """
    Симулятор жизни удава Анатолия. 
    Возвращает число укусов, потребовавшееся, чтобы съесть один батон.
    """

# %% [markdown]
# **ЗАДАЧА 7. Клавдия Леопольдина**
#
# Клавдии Леопольдина подбрасывает кубик до первой шестёрки.
# Обозначим: величина N — число бросков.
# Событие A — при подбрасываниях выпадала только чётная грань.
#
# Оцените $P(N=2), P(N=3), E(N)$
#
# Оцените $P(A), P(N=2|A), P(A|N=2), P(A$ OR $N=2), P(A$ AND $N=2)$

# %%
#ваше решение здесь
def throw_until_six():
    """
    Подбрасываем кубик до первой шестёрки. 
    Считаем число бросков. И следим за тем, выпадали ли только четные числа.
    Возвращает: (число бросков, True/False)
    """
